# %%
# !ls
# Out:
# Flag_research.ipynb README.md           data_rel.csv
# Just check.txt      clear_data.csv      descpription.txt

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats
# %matplotlib inline

# %%
data = pd.read_csv('data_rel.csv', names = ['name', 'landmass', 'zone', 'area', 'population', 'lang', 
                                            'relig', 'bars', 'stripes', 'colours', 'red', 'green',
                                           'blue', 'gold', 'white', 'black', 'orange', 'mainhue',
                                           'circles', 'crosses', 'saltripes', 'quartes', 'sunstars',
                                           'crescent', 'tringle', 'icon', 'animate', 'text', 'topleft',
                                           'botright'], header = None)
data
# Out:
#                      name  landmass  zone   area  population  lang  relig  \
# 0             Afghanistan         5     1    648          16    10      2
# 1                 Albania         3     1     29           3     6      6
# 2                 Algeria         4     1   2388          20     8      2
# 3          American-Samoa         6     3      0           0     1      1
# 4                 Andorra         3     1      0           0     6      0
# 5                  Angola         4     2   1247           7    10      5
# 6                Anguilla         1     4      0           0     1      1
# 7         Antigua-Barbuda         1     4      0           0     1      1
# 8               Argentina         2     3   2777          28     2      0
# 9               Argentine         2     3   2777          28     2      0
# 10              Australia         6     2   7690          15     1      1
# 11                Austria         3     1     84           8     4      0
# ...

# %%
data.to_csv('clear_data.csv', index = False)
data2= pd.read_csv('clear_data.csv')
data2
# Out:
#                      name  landmass  zone   area  population  lang  relig  \
# 0             Afghanistan         5     1    648          16    10      2
# 1                 Albania         3     1     29           3     6      6
# 2                 Algeria         4     1   2388          20     8      2
# 3          American-Samoa         6     3      0           0     1      1
# 4                 Andorra         3     1      0           0     6      0
# 5                  Angola         4     2   1247           7    10      5
# 6                Anguilla         1     4      0           0     1      1
# 7         Antigua-Barbuda         1     4      0           0     1      1
# 8               Argentina         2     3   2777          28     2      0
# 9               Argentine         2     3   2777          28     2      0
# 10              Australia         6     2   7690          15     1      1
# 11                Austria         3     1     84           8     4      0
# ...

# %%
y = data2[['relig']]
y = y['relig']
y
# Out:
# 0      2
# 1      6
# 2      2
# 3      1
# 4      0
# 5      5
# 6      1
# 7      1
# 8      0
# 9      0
# 10     1
# 11     0
# 12     1
# 13     2
# 14     2
# 15     1
# 16     0
# 17     1
# 18     5
# 19     1
# 20     3
# 21     0
# 22     5
# 23     0
# 24     1
# 25     2
# 26     6
# 27     5
# 28     3
# 29     5
#       ..
# 164    1
# 165    1
# 166    1
# 167    2
# 168    3
# 169    5
# 170    3
# 171    7
# 172    1
# 173    1
# 174    2
# 175    2
# 176    1
# 177    1
# 178    2
# 179    5
# 180    1
# 181    0
# 182    1
# 183    1
# 184    6
# 185    1
# 186    0
# 187    0
# 188    6
# 189    1
# 190    6
# 191    5
# 192    5
# 193    5
# Name: relig, dtype: int64

# %%
X = data2
del X['relig']
X
# Out:
#                      name  landmass  zone   area  population  lang  bars  \
# 0             Afghanistan         5     1    648          16    10     0
# 1                 Albania         3     1     29           3     6     0
# 2                 Algeria         4     1   2388          20     8     2
# 3          American-Samoa         6     3      0           0     1     0
# 4                 Andorra         3     1      0           0     6     3
# 5                  Angola         4     2   1247           7    10     0
# 6                Anguilla         1     4      0           0     1     0
# 7         Antigua-Barbuda         1     4      0           0     1     0
# 8               Argentina         2     3   2777          28     2     0
# 9               Argentine         2     3   2777          28     2     0
# 10              Australia         6     2   7690          15     1     0
# 11                Austria         3     1     84           8     4     0
# ...

# %%
X.dtypes
# Out:
# name          object
# landmass       int64
# zone           int64
# area           int64
# population     int64
# lang           int64
# bars           int64
# stripes        int64
# colours        int64
# red            int64
# green          int64
# blue           int64
# gold           int64
# white          int64
# black          int64
# orange         int64
# mainhue       object
# circles        int64
# crosses        int64
# saltripes      int64
# quartes        int64
# sunstars       int64
# crescent       int64
# tringle        int64
# icon           int64
# animate        int64
# text           int64
# topleft       object
# botright      object
# dtype: object

# %%
X.dtypes[X.dtypes.map(lambda x: x=='object')]
# Out:
# name        object
# mainhue     object
# topleft     object
# botright    object
# dtype: object

# %%
z = X[['mainhue', 'topleft', 'botright']]
z.dtypes
# Out:
# mainhue     object
# topleft     object
# botright    object
# dtype: object

# %%
X['topleft_new'] = pd.Categorical.from_array(X.topleft).codes
X['mainhue_new'] = pd.Categorical.from_array(X.mainhue).codes
X['botright_new'] = pd.Categorical.from_array(X.botright).codes
X
# Out:
#                      name  landmass  zone   area  population  lang  bars  \
# 0             Afghanistan         5     1    648          16    10     0
# 1                 Albania         3     1     29           3     6     0
# 2                 Algeria         4     1   2388          20     8     2
# 3          American-Samoa         6     3      0           0     1     0
# 4                 Andorra         3     1      0           0     6     3
# 5                  Angola         4     2   1247           7    10     0
# 6                Anguilla         1     4      0           0     1     0
# 7         Antigua-Barbuda         1     4      0           0     1     0
# 8               Argentina         2     3   2777          28     2     0
# 9               Argentine         2     3   2777          28     2     0
# 10              Australia         6     2   7690          15     1     0
# 11                Austria         3     1     84           8     4     0
# ...

# %%
X.dtypes
# Out:
# name            object
# landmass         int64
# zone             int64
# area             int64
# population       int64
# lang             int64
# bars             int64
# stripes          int64
# colours          int64
# red              int64
# green            int64
# blue             int64
# gold             int64
# white            int64
# black            int64
# orange           int64
# mainhue         object
# circles          int64
# crosses          int64
# saltripes        int64
# quartes          int64
# sunstars         int64
# crescent         int64
# tringle          int64
# icon             int64
# animate          int64
# text             int64
# topleft         object
# botright        object
# topleft_new       int8
# mainhue_new       int8
# botright_new      int8
# dtype: object

# %%
X = X.drop(['name', 'mainhue', 'topleft', 'botright'], axis=1)

# %%
X.dtypes
# Out:
# landmass        int64
# zone            int64
# area            int64
# population      int64
# lang            int64
# bars            int64
# stripes         int64
# colours         int64
# red             int64
# green           int64
# blue            int64
# gold            int64
# white           int64
# black           int64
# orange          int64
# circles         int64
# crosses         int64
# saltripes       int64
# quartes         int64
# sunstars        int64
# crescent        int64
# tringle         int64
# icon            int64
# animate         int64
# text            int64
# topleft_new      int8
# mainhue_new      int8
# botright_new     int8
# dtype: object

# %%
bins = np.arange(9) - 0.5
plt.hist(y, bins, align = 'mid')
# Out:
# (array([ 40.,  60.,  36.,   8.,   4.,  27.,  15.,   4.]),
#  array([-0.5,  0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5]),
#  <a list of 8 Patch objects>)

# %%
from sklearn.cross_validation import train_test_split

# %%
X.shape, y.shape
# Out:
# ((194, 28), (194,))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
X_train.shape, y_train.shape
# Out:
# ((155, 28), (155,))

# %%
X_test.shape, y_test.shape
# Out:
# ((39, 28), (39,))

# %%
from sklearn import metrics
from sklearn.ensemble import ExtraTreesClassifier
model = ExtraTreesClassifier()
model.fit(X, y)
print(model.feature_importances_)
#Всего 25 фич, можно смотреть важность
# Out:
# [ 0.1144255   0.07179626  0.07429279  0.05862244  0.12493001  0.02649474
#   0.05826023  0.03870885  0.02590423  0.04078808  0.03432344  0.03077823
#   0.02924609  0.02610376  0.01299024  0.03071211  0.03941507  0.0269319
#   0.01331806  0.03218291  0.02249818  0.02454712  0.02045459  0.01339677
#   0.00887841]

# %%
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
model.fit(X, y)
print(model.feature_importances_)
# Out:
# [ 0.16330893  0.06183136  0.10911072  0.09472375  0.13974592  0.03454882
#   0.04225464  0.04817534  0.01303123  0.03210815  0.03436789  0.02845503
#   0.01441717  0.01941536  0.01820613  0.02149172  0.03380999  0.00089221
#   0.00673409  0.02582435  0.02166458  0.01246526  0.00890794  0.01140615
#   0.00310326]

# %%
X.describe()
# Out:
#          landmass        zone          area   population        lang  \
# count  194.000000  194.000000    194.000000   194.000000  194.000000
# mean     3.572165    2.211340    700.046392    23.268041    5.340206
# std      1.553018    1.308274   2170.927932    91.934085    3.496517
# min      1.000000    1.000000      0.000000     0.000000    1.000000
# 25%      3.000000    1.000000      9.000000     0.000000    2.000000
# 50%      4.000000    2.000000    111.000000     4.000000    6.000000
# 75%      5.000000    4.000000    471.250000    14.000000    9.000000
# max      6.000000    4.000000  22402.000000  1008.000000   10.000000
#
#              bars     stripes     colours         red       green     ...      \
# count  194.000000  194.000000  194.000000  194.000000  194.000000     ...
# mean     0.453608    1.551546    3.463918    0.788660    0.469072     ...
# std      1.038339    2.328005    1.300154    0.409315    0.500334     ...
# ...

# %%
from sklearn import metrics
from sklearn.svm import SVC
# fit a SVM model to the data
model = SVC(kernel = 'linear', C=1)
model.fit(X_train, y_train)
print(model)
# make predictions
expected = y
predicted = model.predict(X)
# summarize the fit of the model
print(metrics.classification_report(expected, predicted))
# Out:
# SVC(C=1, cache_size=200, class_weight=None, coef0=0.0, degree=3, gamma=0.0,
#   kernel='linear', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)
#              precision    recall  f1-score   support
#
#           0       0.69      0.88      0.77        40
#           1       0.79      0.75      0.77        60
#           2       0.85      0.94      0.89        36
#           3       0.86      0.75      0.80         8
#           4       1.00      0.50      0.67         4
#           5       0.95      0.67      0.78        27
#           6       0.73      0.73      0.73        15
#           7       1.00      0.75      0.86         4
#
# avg / total       0.81      0.79      0.79       194

# %%
def plot_confusion_matrix(predicted, expected):
    plt.imshow(metrics.confusion_matrix(predicted, expected),
               cmap='Blues', interpolation='nearest')
    plt.colorbar()
    plt.xlabel('true value')
    plt.ylabel('predicted value')

# %%
print model.score(X_test, y_test)
print "classification accuracy:", metrics.accuracy_score(predicted, expected)
plot_confusion_matrix(predicted, expected)
print("{0} / {1} correct".format(np.sum(expected == predicted), len(expected)))
# Out:
# 0.435897435897
# classification accuracy: 0.79381443299
# 154 / 194 correct

# %%
data22 = data2.drop(['name', 'mainhue', 'topleft', 'botright'], axis=1) 
data22.dtypes
# Out:
# landmass        int64
# zone            int64
# area            int64
# population      int64
# lang            int64
# bars            int64
# stripes         int64
# colours         int64
# red             int64
# green           int64
# blue            int64
# gold            int64
# white           int64
# black           int64
# orange          int64
# circles         int64
# crosses         int64
# saltripes       int64
# quartes         int64
# sunstars        int64
# crescent        int64
# tringle         int64
# icon            int64
# animate         int64
# text            int64
# topleft_new      int8
# mainhue_new      int8
# botright_new     int8
# dtype: object

# %%
from sklearn.learning_curve import learning_curve
from sklearn import cross_validation

def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,
                        n_jobs=1, train_sizes=np.linspace(.1, 1.0, 5)):
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.legend(loc="best")
    return plt


#digits = load_digits()
#X, y = digits.data, digits.target


title = "Learning Curves (Tree)"
# Cross validation with 100 iterations to get smoother mean test and train
# score curves, each time with 20% data randomly selected as a validation set.
cv = cross_validation.ShuffleSplit(X.shape[0], n_iter=100,
                                   test_size=0.2, random_state=0)

#estimator = GaussianNB()
plot_learning_curve(model_tree, title, X, y, ylim=(0.2, 1.1), cv = cv, n_jobs=4)

title = "Learning Curves (Forest)"
# SVC is more expensive so we do a lower number of CV iterations:
#cv = cross_validation.ShuffleSplit(digits.data.shape[0], n_iter=10,
                                   #test_size=0.2, random_state=0)
#estimator = SVC(gamma=0.001)
plot_learning_curve(model_forest, title, X, y, ylim=(0.2, 1.1), cv=cv, n_jobs=4)

plt.show()

# %%
# %load_ext watermark
# %watermark -a "Rustam Gilaztdinov" -d -v -m -p numpy,scikit-learn,scipy,matplotlib
# Out:
# The watermark extension is already loaded. To reload it, use:
#   %reload_ext watermark
# Rustam Gilaztdinov 15/06/2015
#
# CPython 2.7.9
# IPython 3.1.0
#
# numpy 1.9.2
# scikit-learn 0.16.1
# scipy 0.15.1
# matplotlib 1.4.3
#
# compiler   : GCC 4.2.1 (Apple Inc. build 5666) (dot 3)
# system     : Darwin
# release    : 14.3.0
# machine    : x86_64
# processor  : i386
# CPU cores  : 2
# interpreter: 64bit

# %%
X.shape[0]
# Out:
# 194

# %%
from sklearn.cross_validation import cross_val_score
scores = cross_val_score(model, X, y, cv = 5)
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))

# %%
from sklearn.decomposition import PCA

# instantiate the model
model_pca = PCA(n_components=2)

# fit the model: notice we don't pass the labels!
model_pca.fit(X)

# transform the data to two dimensions
X_PCA = model_pca.transform(X)
print "shape of result:", X_PCA.shape

# plot the results along with the labels
fig, ax = plt.subplots()
im = ax.scatter(X_PCA[:, 0], X_PCA[:, 1], c=y, cmap = 'rainbow')
fig.colorbar(im);
# Out:
# shape of result: (194, 2)

# %%
print model_pca.score(X)
# Out:
# -62.1931855998

# %%
from sklearn import metrics
from sklearn.tree import DecisionTreeClassifier
# fit a CART model to the data
model_tree = DecisionTreeClassifier()
model_tree.fit(X_train, y_train)
print(model_tree)
# make predictions
expected_tree = y
predicted_tree = model_tree.predict(X)
# summarize the fit of the model
print(model_tree.feature_importances_)
print(metrics.classification_report(expected_tree, predicted_tree))
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             random_state=None, splitter='best')
# [ 0.24647017  0.          0.06055527  0.10265078  0.14987268  0.01268973
#   0.03741626  0.04327294  0.01690567  0.          0.03226706  0.
#   0.00704912  0.          0.01074151  0.02233207  0.0668486   0.
#   0.00483368  0.02215437  0.01127859  0.00738479  0.          0.          0.
#   0.05070027  0.05553518  0.03904126]
#              precision    recall  f1-score   support
#
#           0       0.95      0.95      0.95        40
#           1       0.92      0.92      0.92        60
#           2       0.95      0.97      0.96        36
#           3       1.00      0.88      0.93         8
#           4       0.80      1.00      0.89         4
#           5       1.00      0.81      0.90        27
# ...

# %%
print "model_score:", model_tree.score(X, y)
print "classification accuracy:", metrics.accuracy_score(predicted_tree, expected_tree)
plot_confusion_matrix(predicted_tree, expected_tree)
print("{0} / {1} correct".format(np.sum(expected_tree == predicted_tree), len(expected_tree)))
# Out:
# model_score: 0.922680412371
# classification accuracy: 0.922680412371
# 179 / 194 correct

# %%
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
# fit a CART model to the data
model_forest = DecisionTreeClassifier()
model_forest.fit(X_train, y_train)
print(model_forest)
# make predictions
expected_forest = y
predicted_forest = model_forest.predict(X)
# summarize the fit of the model
print(model_forest.feature_importances_)
print(metrics.classification_report(expected_forest, predicted_forest))
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             random_state=None, splitter='best')
# [ 0.24647017  0.          0.06793268  0.08976096  0.14987268  0.01427594
#   0.02237815  0.04327294  0.01690567  0.01879764  0.03226706  0.
#   0.00704912  0.          0.          0.02074586  0.0668486   0.          0.
#   0.02309425  0.01933472  0.0202746   0.          0.01409823  0.
#   0.03190263  0.06052428  0.03419381]
#              precision    recall  f1-score   support
#
#           0       0.95      0.95      0.95        40
#           1       0.95      0.93      0.94        60
#           2       0.92      0.97      0.95        36
#           3       0.88      0.88      0.88         8
#           4       0.80      1.00      0.89         4
#           5       1.00      0.89      0.94        27
# ...

# %%
print "model_score:", model_forest.score(X, y)
print "classification accuracy:", metrics.accuracy_score(predicted_forest, expected_forest)
plot_confusion_matrix(predicted_forest, expected_forest)
print("{0} / {1} correct".format(np.sum(expected_forest == predicted_forest), len(expected_forest)))
# Out:
# model_score: 0.938144329897
# classification accuracy: 0.938144329897
# 182 / 194 correct

# %%
from sklearn import metrics
from sklearn.linear_model import LogisticRegression
model_reg = LogisticRegression()
model_reg.fit(X, y)
print(model_reg)
# make predictions
expected_reg = y
predicted_reg = model_reg.predict(X)
# summarize the fit of the model
print(metrics.classification_report(expected_reg, predicted_reg))
# Out:
#  LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr',
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0)
#              precision    recall  f1-score   support
#
#           0       0.68      0.65      0.67        40
#           1       0.74      0.72      0.73        60
#           2       0.70      0.83      0.76        36
#           3       1.00      0.62      0.77         8
#           4       1.00      0.25      0.40         4
#           5       0.59      0.70      0.64        27
#           6       0.62      0.53      0.57        15
#           7       0.75      0.75      0.75         4
#
# avg / total       0.71      0.70      0.69       194

# %%
print "model_score:", model_reg.score(X, y)
print "classification accuracy:", metrics.accuracy_score(predicted_reg, expected_reg)
plot_confusion_matrix(predicted_reg, expected_reg)
print("{0} / {1} correct".format(np.sum(expected_reg == predicted_reg), len(expected_reg)))
# Out:
# model_score: 0.69587628866
# classification accuracy: 0.69587628866
# 135 / 194 correct

# %%
from sklearn.cross_validation import cross_val_score
cross_val_score(model, X, y)
# Out:
# array([ 0.47761194,  0.484375  ,  0.53968254])

# %%
cross_val_score(model_tree, X, y)
# Out:
# array([ 0.55223881,  0.515625  ,  0.57142857])

# %%
cross_val_score(model_forest, X, y)
# Out:
# array([ 0.58208955,  0.53125   ,  0.53968254])

# %% [markdown]
# Левый стафф

# %%
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.grid_search import GridSearchCV
from sklearn.svm import SVC
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectKBest

# %%
from sklearn.cross_validation import ShuffleSplit
cv = ShuffleSplit(X_train.shape[0], n_iter=10, test_size=0.2, random_state=0)

# %%
pca = PCA(n_components=2)

# Maybe some original features where good, too?
selection = SelectKBest(k=1)

# Build estimator from PCA and Univariate selection:

combined_features = FeatureUnion([("pca", pca), ("univ_select", selection)])

# Use combined features to transform dataset:
X_features = combined_features.fit(X, y).transform(X)

svm = SVC(kernel="linear")

# Do grid search over k, n_components and C:

pipeline = Pipeline([("features", combined_features), ("svm", svm)])

param_grid = dict(features__pca__n_components=[1, 2, 3],
                  features__univ_select__k=[1, 2],
                  svm__C=[0.1, 1, 10])

grid_search = GridSearchCV(pipeline, param_grid=param_grid, verbose=10)
grid_search.fit(X, y)
print(grid_search.best_estimator_)
# Out:
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# [CV] features__pca__n_components=1, svm__C=0.1, features__univ_select__k=1
# [CV]  features__pca__n_components=1, svm__C=0.1, features__univ_select__k=1, score=0.388060 -  21.7s

# %%
from sklearn.cross_validation import cross_val_score
cv = cross_val_score(model, X, y, cv=3)
cv.mean()
